# %%
from  sklearn import  datasets
iris=datasets.load_iris()

# %%
import pandas as pd

# %%
iris.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-e8f0cfa3a06e> in <module>
# ----> 1 iris["key"]
#
# KeyError: 'key'
